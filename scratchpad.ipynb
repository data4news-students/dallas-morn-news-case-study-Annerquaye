# %% [markdown]
# # Scratchpad - Dallas Morning News Case Study
#
# The Dallas Morning News [uncovers a cheating scandal on the TAKS test](http://clipfile.org/?p=754).
#
# Analyze the data below first, and then see if your findings match the ones in the clip above. Try not to consult the clip above unless you're stuck. The clip also doesn't contain all of the answers so there is still plenty to investigate.
#
#
# You've recieved a tip that a fourth grade classroom at Harrell Budd Elementary in southern Dallas has unusually high test scores in reading on the TAKS test (the state's standardized test to measure student progress). To check out this claim you've downloaded data from the Texas Education Agency.
#
# Let's see how the Dallas Morning News used regressions to find evidence of this claim and try to find out if it is an isolated case.

# %% [markdown]
# ### Prep work: Downloading necessary files
# Before we get started, we need to download all of the data we'll be using.
# * **cfy04e4.dat:** 2004 fourth-grade TAKS scores - standardized test scores for 2004's fourth-graders
# * **cfy04e5.dat:** 2004 fifth-grade TAKS scores - standardized test scores for 2004's fifth-graders
# * **cfy04e3.dat:** 2004 third-grade TAKS scores - standardized test scores for 2004's third-graders
#
# More data you might want
# * **cfy03e3.dat:** 2003 third-grade TAKS scores - standardized test scores for 2003's third-graders
#
# Data Documentation:
# https://tea.texas.gov/student-assessment/testing/taks-resources/taks-variables-formats-and-descriptions

# %%
# !brew install wget
# Out:
# Running `brew update --preinstall`...
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/core, homebrew/cask and homebrew/services).
# ==> New Formulae
# alpscore                   kdoctor                    tarlz
# ascii2binary               kopia                      terminalimageviewer
# asyncapi                   kubescape                  terraform-lsp
# atlas                      kyverno                    textidote
# bk                         librasterlite2             tfschema
# boost@1.76                 linode-cli                 tidy-viewer
# brev                       linux-headers@5.16         usbutils
# canfigger                  numdiff                    vermin
# csview                     odo-dev                    vkectl
# elvis                      oh-my-posh                 webp-pixbuf-loader
# esphome                    reshape                    websocketpp
# fb303                      ruby@3.0                   weggli
# ffmpeg@4                   rure                       xidel
# ghcup                      spago                      yamale
# inotify-tools              sshs
# jless                      tagref
# ==> Updated Formulae
# Updated 1168 formulae.
# ==> Deleted Formulae
# carina              go@1.11             go@1.9              path-extractor
# go@1.10             go@1.12             hornetq
# ==> New Casks
# arctype             inkstitch           openshift-client    sonic-lineup
# devtoys             kindavim            panwriter           thinlinc-client
# hackolade           manyverse           polypane            threema-work
# heroic              music-bar           presentation        trex
# hostsx              mysteriumvpn        quarto              ujam
# imagex              nozbe-personal      quit-all
# ==> Updated Casks
# Updated 968 casks.
# ==> Deleted Casks
# airqmon                                  lilypond
# finisher-voodoo                          liya
# hocus-focus                              mathinspector
# hoststool                                mediahuman-audio-converter
# jiohome                                  nozbe
# jsui                                     powerword
# knox                                     telavox-flow
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:df13d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2022-
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:40
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:4f8b66c5f181f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for wget: libunistring and ca-certificates
# ==> Installing wget dependency: libunistring
# ==> Pouring libunistring--1.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.0: 56 files, 4.8MB
# ==> Installing wget dependency: ca-certificates
# ==> Pouring ca-certificates--2022-02-01.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2022-02-01: 3 files, 213.4KB
# ==> Installing wget
# ==> Pouring wget--1.21.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/wget/1.21.2: 89 files, 4.2MB
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /opt/homebrew/Cellar/ca-certificates/2021-10-26... (3 files, 208.5KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/ca-certificates--2021-10-26... (117.6KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/ffmpeg--4.4.1_3... (18.4MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/gdbm--1.22... (258.2KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/gnutls--3.6.16_1... (3.0MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/guile--3.0.7_2... (11.6MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/imath--3.1.3... (180.6KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/jpeg--9d... (308.9KB)
# Removing: /opt/homebrew/Cellar/libunistring/0.9.10... (55 files, 4.4MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/little-cms2--2.12... (401.8KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/openblas--0.3.19... (14.6MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/openexr--3.1.3... (1.4MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/p11-kit--0.24.0_1... (755.6KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/readline--8.1.1... (560.7KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/rubberband--2.0.0... (344.3KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/ruby--3.0.3... (11.2MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/ruby-build--20211227... (57.0KB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/unbound--1.13.2_1... (2.7MB)
# Removing: /Users/richardabbey/Library/Caches/Homebrew/webp--1.2.1_1... (765.3KB)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/mpfr... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/libyaml... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/gcc... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/ruby-build... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/openblas... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/zstd... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/isl... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/ruby... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/rbenv... (64B)
# Removing: /Users/richardabbey/Library/Logs/Homebrew/libmpc... (64B)
# ==> Upgrading 18 dependents:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# glib 2.70.1 -> 2.70.4, guile 3.0.7_2 -> 3.0.8, ffmpeg 4.4.1_3 -> 5.0, gnutls 3.6.16_1 -> 3.7.3, gobject-introspection 1.70.0_1 -> 1.70.0_3, harfbuzz 3.1.1 -> 3.4.0, libraqm 0.7.2 -> 0.9.0, ocrmypdf 12.7.2 -> 13.4.0, pipenv 2021.11.15 -> 2022.1.8, postgresql 14.0 -> 14.2, pyenv 2.1.0 -> 2.2.4-1, python@3.10 3.10.0_2 -> 3.10.2, python@3.9 3.9.8 -> 3.9.10, ruby 3.0.3 -> 3.1.1, tcl-tk 8.6.12 -> 8.6.12_1, pillow 8.4.0 -> 9.0.1, unbound 1.13.2_1 -> 1.15.0, unpaper 6.1_7 -> 6.1_8
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/manifests/1.23
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/blobs/sha256:09f52f15b2a2d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.1.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:08efc469d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.37.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:ee147de3d4d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.10/manifests/3.10.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.10/blobs/sha256:38c1e4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ruby/manifests/3.1.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ruby/blobs/sha256:3d1b5f14c7235
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/manifests/8.6.12_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/blobs/sha256:6097b84f40a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/manifests/3.0.8
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/blobs/sha256:f8f697d08fcd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.15.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:8602cf8aad
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.24.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:c861097640
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.7.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:93285dd80fe
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:07244e9
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.70.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:9b2c85257af95
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.11.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:7621db36f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.14_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:e473ad5c087
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.7.3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:043f7cc4249
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/3.4.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:4a62926c8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libraqm/manifests/0.9.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libraqm/blobs/sha256:118bb1b1da
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/manifests/9e
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/blobs/sha256:27409eb75ac18
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libimagequant/manifests/4.0.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libimagequant/blobs/sha256:87b6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.13.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:e78f36
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:9b8ae542d86b3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pillow/manifests/9.0.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pillow/blobs/sha256:dce572358d1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:990f0df58bc0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.1.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:991ec0d21d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:e1e3ce34ca
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.6_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:417402199b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.5.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:f87657ce277b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/2.0.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:91d2587
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.0.20
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:7aca35ed5898e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/blobs/sha256:7713b483f347
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:1d915415cff308
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.6.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:aaba8a0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.0.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/blobs/sha256:be55b6ba
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/4/manifests/4.4.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/4/blobs/sha256:545c2a76d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unpaper/manifests/6.1_8
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unpaper/blobs/sha256:af3c1cb708
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pngquant/manifests/2.17.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pngquant/blobs/sha256:381b9ea76
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pybind11/manifests/2.9.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pybind11/blobs/sha256:52ad809ed
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qpdf/manifests/10.6.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qpdf/blobs/sha256:042f245db2393
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ocrmypdf/manifests/13.4.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ocrmypdf/blobs/sha256:425081044
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pipenv/manifests/2022.1.8
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pipenv/blobs/sha256:f664076e51a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/manifests/14.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/blobs/sha256:b0cbdfc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyenv/manifests/2.2.4-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyenv/blobs/sha256:24b0dc8ff20a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/5.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:877fe3b70a3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading python@3.10
#   3.10.0_2 -> 3.10.2
#
# ==> Installing dependencies for python@3.10: gdbm, readline and sqlite
# ==> Installing python@3.10 dependency: gdbm
# ==> Pouring gdbm--1.23.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gdbm/1.23: 24 files, 1MB
# ==> Installing python@3.10 dependency: readline
# ==> Pouring readline--8.1.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/readline/8.1.2: 48 files, 1.7MB
# ==> Installing python@3.10 dependency: sqlite
# ==> Pouring sqlite--3.37.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/sqlite/3.37.2: 11 files, 4.3MB
# ==> Installing python@3.10
# ==> Pouring python@3.10--3.10.2.arm64_big_sur.bottle.tar.gz
# ==> /opt/homebrew/Cellar/python@3.10/3.10.2/bin/python3 -m ensurepip
# ==> /opt/homebrew/Cellar/python@3.10/3.10.2/bin/python3 -m pip install -v --no-d
# 🍺  /opt/homebrew/Cellar/python@3.10/3.10.2: 3,135 files, 57.2MB
# ==> Running `brew cleanup python@3.10`...
# Removing: /opt/homebrew/Cellar/python@3.10/3.10.0_2... (3,135 files, 57.7MB)
# ==> Upgrading ruby
#   3.0.3 -> 3.1.1
#
# ==> Pouring ruby--3.1.1.arm64_big_sur.bottle.tar.gz
# ==> Caveats
# By default, binaries installed by gem will be placed into:
#   /opt/homebrew/lib/ruby/gems/3.1.0/bin
#
# You may want to add this to your PATH.
#
# ruby is keg-only, which means it was not symlinked into /opt/homebrew,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have ruby first in your PATH, run:
#   echo 'export PATH="/opt/homebrew/opt/ruby/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find ruby you may need to set:
#   export LDFLAGS="-L/opt/homebrew/opt/ruby/lib"
#   export CPPFLAGS="-I/opt/homebrew/opt/ruby/include"
#
# For pkg-config to find ruby you may need to set:
#   export PKG_CONFIG_PATH="/opt/homebrew/opt/ruby/lib/pkgconfig"
#
# ==> Summary
# 🍺  /opt/homebrew/Cellar/ruby/3.1.1: 15,960 files, 44.3MB
# ==> Running `brew cleanup ruby`...
# Removing: /opt/homebrew/Cellar/ruby/3.0.3... (16,540 files, 41.3MB)
# ==> Upgrading tcl-tk
#   8.6.12 -> 8.6.12_1
#
# ==> Pouring tcl-tk--8.6.12_1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tcl-tk/8.6.12_1: 3,045 files, 52.1MB
# ==> Running `brew cleanup tcl-tk`...
# Removing: /opt/homebrew/Cellar/tcl-tk/8.6.12... (3,046 files, 52.2MB)
# ==> Upgrading guile
#   3.0.7_2 -> 3.0.8
#
# ==> Pouring guile--3.0.8.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/guile/3.0.8: 846 files, 62.7MB
# ==> Running `brew cleanup guile`...
# Removing: /opt/homebrew/Cellar/guile/3.0.7_2... (838 files, 56.8MB)
# ==> Upgrading unbound
#   1.13.2_1 -> 1.15.0
#
# ==> Pouring unbound--1.15.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/unbound/1.15.0: 58 files, 5.8MB
# ==> Running `brew cleanup unbound`...
# Removing: /opt/homebrew/Cellar/unbound/1.13.2_1... (57 files, 5.7MB)
# ==> Upgrading gnutls
#   3.6.16_1 -> 3.7.3
#
# ==> Installing dependencies for gnutls: p11-kit
# ==> Installing gnutls dependency: p11-kit
# ==> Pouring p11-kit--0.24.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/p11-kit/0.24.1: 67 files, 3.9MB
# ==> Installing gnutls
# ==> Pouring gnutls--3.7.3.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gnutls/3.7.3: 1,280 files, 11MB
# ==> Running `brew cleanup gnutls`...
# Removing: /opt/homebrew/Cellar/gnutls/3.6.16_1... (1,250 files, 11.2MB)
# ==> Upgrading python@3.9
#   3.9.8 -> 3.9.10
#
# ==> Pouring python@3.9--3.9.10.arm64_big_sur.bottle.tar.gz
# ==> /opt/homebrew/Cellar/python@3.9/3.9.10/bin/python3 -m ensurepip
# ==> /opt/homebrew/Cellar/python@3.9/3.9.10/bin/python3 -m pip install -v --no-de
# 🍺  /opt/homebrew/Cellar/python@3.9/3.9.10: 3,082 files, 56.9MB
# ==> Running `brew cleanup python@3.9`...
# Removing: /opt/homebrew/Cellar/python@3.9/3.9.8... (3,082 files, 56.9MB)
# ==> Upgrading glib
#   2.70.1 -> 2.70.4
#
# ==> Pouring glib--2.70.4.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/glib/2.70.4: 444 files, 22.2MB
# ==> Running `brew cleanup glib`...
# Removing: /opt/homebrew/Cellar/glib/2.70.1... (444 files, 22MB)
# ==> Upgrading gobject-introspection
#   1.70.0_1 -> 1.70.0_3
#
# ==> Installing dependencies for gobject-introspection: freetype, libxcb and libx11
# ==> Installing gobject-introspection dependency: freetype
# ==> Pouring freetype--2.11.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/freetype/2.11.1: 66 files, 2.2MB
# ==> Installing gobject-introspection dependency: libxcb
# ==> Pouring libxcb--1.14_2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxcb/1.14_2: 2,452 files, 7.3MB
# ==> Installing gobject-introspection dependency: libx11
# ==> Pouring libx11--1.7.3.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libx11/1.7.3.1: 1,055 files, 7.1MB
# ==> Installing gobject-introspection
# ==> Pouring gobject-introspection--1.70.0_3.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gobject-introspection/1.70.0_3: 191 files, 13MB
# ==> Running `brew cleanup gobject-introspection`...
# Removing: /opt/homebrew/Cellar/gobject-introspection/1.70.0_1... (191 files, 13MB)
# ==> Upgrading harfbuzz
#   3.1.1 -> 3.4.0
#
# ==> Pouring harfbuzz--3.4.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/3.4.0: 68 files, 7.3MB
# ==> Running `brew cleanup harfbuzz`...
# Removing: /opt/homebrew/Cellar/harfbuzz/3.1.1... (68 files, 7.1MB)
# ==> Upgrading libraqm
#   0.7.2 -> 0.9.0
#
# ==> Pouring libraqm--0.9.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libraqm/0.9.0: 11 files, 106KB
# ==> Running `brew cleanup libraqm`...
# Removing: /opt/homebrew/Cellar/libraqm/0.7.2... (26 files, 205.7KB)
# ==> Upgrading pillow
#   8.4.0 -> 9.0.1
#
# ==> Installing dependencies for pillow: jpeg, libimagequant, little-cms2 and webp
# ==> Installing pillow dependency: jpeg
# ==> Pouring jpeg--9e.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg/9e: 21 files, 1001.4KB
# ==> Installing pillow dependency: libimagequant
# ==> Pouring libimagequant--4.0.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libimagequant/4.0.0: 11 files, 12.9MB
# ==> Installing pillow dependency: little-cms2
# ==> Pouring little-cms2--2.13.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/little-cms2/2.13.1: 21 files, 1.4MB
# ==> Installing pillow dependency: webp
# ==> Pouring webp--1.2.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/webp/1.2.2: 41 files, 2.3MB
# ==> Installing pillow
# ==> Pouring pillow--9.0.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pillow/9.0.1: 317 files, 5.8MB
# ==> Running `brew cleanup pillow`...
# Removing: /opt/homebrew/Cellar/pillow/8.4.0... (317 files, 5.8MB)
# ==> Upgrading unpaper
#   6.1_7 -> 6.1_8
#
# ==> Installing dependencies for unpaper: imath, openexr, mbedtls, librist, rav1e, rubberband, sdl2, libb2, lz4, libarchive, tesseract and ffmpeg@4
# ==> Installing unpaper dependency: imath
# ==> Pouring imath--3.1.4.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imath/3.1.4: 49 files, 927.3KB
# ==> Installing unpaper dependency: openexr
# ==> Pouring openexr--3.1.4.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.1.4: 194 files, 6.2MB
# ==> Installing unpaper dependency: mbedtls
# ==> Pouring mbedtls--3.1.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mbedtls/3.1.0: 152 files, 10.6MB
# ==> Installing unpaper dependency: librist
# ==> Pouring librist--0.2.6_1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/librist/0.2.6_1: 20 files, 829.0KB
# ==> Installing unpaper dependency: rav1e
# ==> Pouring rav1e--0.5.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rav1e/0.5.1: 13 files, 111.3MB
# ==> Installing unpaper dependency: rubberband
# ==> Pouring rubberband--2.0.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rubberband/2.0.2: 12 files, 1MB
# ==> Installing unpaper dependency: sdl2
# ==> Pouring sdl2--2.0.20.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/sdl2/2.0.20: 92 files, 5.6MB
# ==> Installing unpaper dependency: libb2
# ==> Pouring libb2--0.98.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libb2/0.98.1: 8 files, 126.8KB
# ==> Installing unpaper dependency: lz4
# ==> Pouring lz4--1.9.3.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lz4/1.9.3: 22 files, 629.4KB
# ==> Installing unpaper dependency: libarchive
# ==> Pouring libarchive--3.6.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libarchive/3.6.0: 62 files, 3.7MB
# ==> Installing unpaper dependency: tesseract
# ==> Pouring tesseract--5.0.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tesseract/5.0.1: 58 files, 30MB
# ==> Installing unpaper dependency: ffmpeg@4
# ==> Pouring ffmpeg@4--4.4.1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg@4/4.4.1: 276 files, 48.2MB
# ==> Installing unpaper
# ==> Pouring unpaper--6.1_8.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/unpaper/6.1_8: 38 files, 535.1KB
# ==> Running `brew cleanup unpaper`...
# Removing: /opt/homebrew/Cellar/unpaper/6.1_7... (38 files, 534.6KB)
# ==> Upgrading ocrmypdf
#   12.7.2 -> 13.4.0
#
# ==> Installing dependencies for ocrmypdf: pngquant, pybind11 and qpdf
# ==> Installing ocrmypdf dependency: pngquant
# ==> Pouring pngquant--2.17.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pngquant/2.17.0: 7 files, 178KB
# ==> Installing ocrmypdf dependency: pybind11
# ==> Pouring pybind11--2.9.0.all.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pybind11/2.9.0: 192 files, 2.8MB
# ==> Installing ocrmypdf dependency: qpdf
# ==> Pouring qpdf--10.6.2.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/qpdf/10.6.2: 82 files, 9.5MB
# ==> Installing ocrmypdf
# ==> Pouring ocrmypdf--13.4.0.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ocrmypdf/13.4.0: 1,485 files, 32.6MB
# ==> Running `brew cleanup ocrmypdf`...
# Removing: /opt/homebrew/Cellar/ocrmypdf/12.7.2... (1,429 files, 31.2MB)
# ==> Upgrading pipenv
#   2021.11.15 -> 2022.1.8
#
# ==> Pouring pipenv--2022.1.8.arm64_big_sur.bottle.tar.gz
# ==> Caveats
# zsh completions have been installed to:
#   /opt/homebrew/share/zsh/site-functions
# ==> Summary
# 🍺  /opt/homebrew/Cellar/pipenv/2022.1.8: 1,767 files, 28MB
# ==> Running `brew cleanup pipenv`...
# Removing: /opt/homebrew/Cellar/pipenv/2021.11.15... (1,769 files, 26.9MB)
# ==> Upgrading postgresql
#   14.0 -> 14.2
#
# ==> Pouring postgresql--14.2.arm64_big_sur.bottle.tar.gz
# ==> Caveats
# To migrate existing data from a previous major version of PostgreSQL run:
#   brew postgresql-upgrade-database
#
# This formula has created a default database cluster with:
#   initdb --locale=C -E UTF-8 /opt/homebrew/var/postgres
# For more details, read:
#   https://www.postgresql.org/docs/14/app-initdb.html
#
# To restart postgresql after an upgrade:
#   brew services restart postgresql
# Or, if you don't want/need a background service you can just run:
#   /opt/homebrew/opt/postgresql/bin/postgres -D /opt/homebrew/var/postgres
# ==> Summary
# 🍺  /opt/homebrew/Cellar/postgresql/14.2: 3,305 files, 46.2MB
# ==> Running `brew cleanup postgresql`...
# Removing: /opt/homebrew/Cellar/postgresql/14.0... (3,302 files, 45.7MB)
# ==> Upgrading pyenv
#   2.1.0 -> 2.2.4-1
#
# ==> Pouring pyenv--2.2.4-1.arm64_big_sur.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pyenv/2.2.4-1: 859 files, 2.9MB
# ==> Running `brew cleanup pyenv`...
# Removing: /opt/homebrew/Cellar/pyenv/2.1.0... (819 files, 2.8MB)
# ==> Upgrading ffmpeg
#   4.4.1_3 -> 5.0
#
# ==> Pouring ffmpeg--5.0.arm64_big_sur.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg/5.0: 272 files, 48.8MB
# ==> Running `brew cleanup ffmpeg`...
# Removing: /opt/homebrew/Cellar/ffmpeg/4.4.1_3... (276 files, 48.2MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> Caveats
# ==> ruby
# By default, binaries installed by gem will be placed into:
#   /opt/homebrew/lib/ruby/gems/3.1.0/bin
#
# You may want to add this to your PATH.
#
# ruby is keg-only, which means it was not symlinked into /opt/homebrew,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have ruby first in your PATH, run:
#   echo 'export PATH="/opt/homebrew/opt/ruby/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find ruby you may need to set:
#   export LDFLAGS="-L/opt/homebrew/opt/ruby/lib"
#   export CPPFLAGS="-I/opt/homebrew/opt/ruby/include"
#
# For pkg-config to find ruby you may need to set:
#   export PKG_CONFIG_PATH="/opt/homebrew/opt/ruby/lib/pkgconfig"
#
# ==> pipenv
# zsh completions have been installed to:
#   /opt/homebrew/share/zsh/site-functions
# ==> postgresql
# To migrate existing data from a previous major version of PostgreSQL run:
#   brew postgresql-upgrade-database
#
# This formula has created a default database cluster with:
#   initdb --locale=C -E UTF-8 /opt/homebrew/var/postgres
# For more details, read:
#   https://www.postgresql.org/docs/14/app-initdb.html
#
# To restart postgresql after an upgrade:
#   brew services restart postgresql
# Or, if you don't want/need a background service you can just run:
#   /opt/homebrew/opt/postgresql/bin/postgres -D /opt/homebrew/var/postgres

# %%
# Make data directory if it doesn't exist
# !mkdir -p data
# !wget -nc https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e4.dat -P data
# !wget -nc https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy03e3.dat -P data
# !wget -nc https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e5.dat -P data
# !wget -nc https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e3.dat -P data
# Out:
# --2022-02-22 15:36:12--  https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e4.dat
# Resolving nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15699181 (15M) [application/octet-stream]
# Saving to: ‘data/cfy04e4.dat’
#
# cfy04e4.dat         100%[===================>]  14.97M  9.46MB/s    in 1.6s
#
# 2022-02-22 15:36:14 (9.46 MB/s) - ‘data/cfy04e4.dat’ saved [15699181/15699181]
#
# --2022-02-22 15:36:14--  https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy03e3.dat
# Resolving nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11669172 (11M) [application/octet-stream]
# Saving to: ‘data/cfy03e3.dat’
#
# cfy03e3.dat         100%[===================>]  11.13M  9.50MB/s    in 1.2s
#
# 2022-02-22 15:36:15 (9.50 MB/s) - ‘data/cfy03e3.dat’ saved [11669172/11669172]
#
# --2022-02-22 15:36:15--  https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e5.dat
# Resolving nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14220152 (14M) [application/octet-stream]
# Saving to: ‘data/cfy04e5.dat’
#
# cfy04e5.dat         100%[===================>]  13.56M  6.17MB/s    in 2.2s
#
# 2022-02-22 15:36:18 (6.17 MB/s) - ‘data/cfy04e5.dat’ saved [14220152/14220152]
#
# --2022-02-22 15:36:18--  https://nyc3.digitaloceanspaces.com/ml-files-distro/v1/dmn-texas-school-cheating/data/cfy04e3.dat
# Resolving nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)... 162.243.189.2
# Connecting to nyc3.digitaloceanspaces.com (nyc3.digitaloceanspaces.com)|162.243.189.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11858431 (11M) [application/octet-stream]
# Saving to: ‘data/cfy04e3.dat’
#
# cfy04e3.dat         100%[===================>]  11.31M  8.73MB/s    in 1.3s
#
# 2022-02-22 15:36:19 (8.73 MB/s) - ‘data/cfy04e3.dat’ saved [11858431/11858431]

# %% [markdown]
# ## Finding suspicious behavior by tracking down outliers

# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

from plotnine import *

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 200)

# %% [markdown]
# # Reading 2004 test scores data
#
# We'll start by opening up our dataset - standardized test performance at each school, for third, fourth and fifth graders in 2004 in both math and reading.

# %%
df_third_grade_2004 = pd.read_csv("data/cfy04e3.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_third')
df_fourth_grade_2004 = pd.read_csv("data/cfy04e4.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_fourth')
df_fifth_grade_2004 = pd.read_csv("data/cfy04e5.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_fifth')

df_2004 = pd.concat([df_third_grade_2004, df_fourth_grade_2004, df_fifth_grade_2004], axis=1)
df_2004['CNAME'] = df_2004['CNAME_third'].fillna(df_2004['CNAME_fourth']).fillna(df_2004['CNAME_fifth'])
df_2004 = df_2004.drop(columns=['CNAME_third', 'CNAME_fourth', 'CNAME_fifth'])

df = df_2004.reset_index()


df
# Out:
#          CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  \
# 0       1902103          2410.0          2388.0           2392.0
# 1       1903101          2256.0          2208.0           2263.0
# 2       1904102          2284.0          2313.0           2242.0
# 3       1906102          2294.0          2273.0           2218.0
# 4       1907110          2256.0          2205.0           2200.0
# ...         ...             ...             ...              ...
# 4232  253901106          2198.0          2253.0           2172.0
# 4233  253901107          2190.0          2178.0           2155.0
# 4234  254901104             NaN             NaN           2176.0
# 4235  254901105          2183.0          2180.0              NaN
# 4236  254902101          2204.0          2159.0           2181.0
#
#       m_all_rs_fourth  r_all_rs_fifth  m_all_rs_fifth            CNAME
# 0              2227.0          2308.0          2317.0        CAYUGA EL
# 1              2192.0          2193.0          2153.0       ELKHART EL
# 2              2152.0          2288.0          2256.0     FRANKSTON EL
# 3              2096.0          2298.0          2312.0        NECHES EL
# 4              2168.0          2218.0          2269.0         STORY EL
# ...               ...             ...             ...              ...
# 4232           2181.0          2140.0          2202.0  ZAPATA SOUTH EL
# 4233           2171.0          2076.0          2168.0   ZAPATA CENTRAL
# 4234           2148.0          2089.0          2053.0  BENITO JUAREZ E
# 4235              NaN             NaN             NaN  LORENZO DE ZAVA
# 4236           2224.0          2122.0          2211.0      LA PRYOR EL
#
# [4237 rows x 8 columns]

# %%
# Here is the dataframe above in long format if you'd prefer it that way!
df_long = df.melt(id_vars=['CAMPUS', 'CNAME']).dropna()
df_long
# Out:
#           CAMPUS            CNAME        variable   value
# 0        1902103        CAYUGA EL  r_all_rs_third  2410.0
# 1        1903101       ELKHART EL  r_all_rs_third  2256.0
# 2        1904102     FRANKSTON EL  r_all_rs_third  2284.0
# 3        1906102        NECHES EL  r_all_rs_third  2294.0
# 4        1907110         STORY EL  r_all_rs_third  2256.0
# ...          ...              ...             ...     ...
# 25416  253901101     BENAVIDES EL  m_all_rs_fifth  2088.0
# 25417  253901106  ZAPATA SOUTH EL  m_all_rs_fifth  2202.0
# 25418  253901107   ZAPATA CENTRAL  m_all_rs_fifth  2168.0
# 25419  254901104  BENITO JUAREZ E  m_all_rs_fifth  2053.0
# 25421  254902101      LA PRYOR EL  m_all_rs_fifth  2211.0
#
# [21814 rows x 4 columns]

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Descriptive Stats

# %%
df.describe().round(1)
# Out:
#             CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  \
# count       4237.0          3745.0          3749.0           3706.0
# mean   115343592.6          2274.5          2238.9           2227.2
# std     71979517.5            63.2            74.8             68.6
# min      1902103.0          1858.0          1924.0           1951.0
# 25%     57909110.0          2234.0          2193.0           2181.0
# 50%    101912217.0          2276.0          2239.0           2226.0
# 75%    178902103.0          2318.0          2288.0           2273.0
# max    254902101.0          2503.0          2497.0           2509.0
#
#        m_all_rs_fourth  r_all_rs_fifth  m_all_rs_fifth
# count           3709.0          3453.0          3452.0
# mean            2217.5          2202.5          2220.4
# std               78.5            89.0            98.3
# min             1898.0          1805.0          1816.0
# 25%             2168.0          2141.0          2157.0
# 50%             2216.0          2200.0          2216.0
# 75%             2268.0          2260.0          2282.0
# max             2520.0          2476.0          2696.0

# %% [markdown]
# ### Example Histogram

# %%
to_plot = df.query('r_all_rs_fourth.notna()')

(
    ggplot(to_plot, aes(x='r_all_rs_fourth')) + 
        geom_histogram(bins=20)
)
# Out:
# <ggplot: (377401697)>

# %% [markdown]
# ## Example Scatter Plot

# %%
to_plot = df.query('r_all_rs_fourth.notna() and r_all_rs_third.notna()')
to_highlight = to_plot.query('CNAME.str.contains(\'HARRELL BUDD\')')

(
    ggplot(to_plot, aes(x='r_all_rs_third', y='r_all_rs_fourth')) + 
        geom_point() + 
        geom_smooth(method='lm', color='red') + 
        geom_point(data=to_highlight, color='red')
)
# Out:
# <ggplot: (378808354)>

# %% [markdown]
# ## Example Regression
#
# Using a regression to predict fourth-grade reading scores

# %%
import statsmodels.formula.api as smf

df = df.query('r_all_rs_fourth.notna() and r_all_rs_third.notna()')
model = smf.ols("r_all_rs_fourth ~ r_all_rs_third", data=df)

results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        r_all_rs_fourth   R-squared:                       0.490
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     3410.
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):               0.00
# Time:                        15:43:38   Log-Likelihood:                -18903.
# No. Observations:                3557   AIC:                         3.781e+04
# Df Residuals:                    3555   BIC:                         3.782e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        504.0130     29.526     17.070      0.000     446.123     561.903
# r_all_rs_third     0.7579      0.013     58.398      0.000       0.732       0.783
# ==============================================================================
# Omnibus:                      182.214   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              599.474
# Skew:                          -0.164   Prob(JB):                    6.70e-131
# Kurtosis:                       4.984   Cond. No.                     8.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Comparing actual to predicted values
df['actual'] = df.r_all_rs_fourth
df['predicted'] = results.predict()
df
# Out:
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/2243843013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/2243843013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  \
# 0       1902103          2410.0          2388.0           2392.0
# 1       1903101          2256.0          2208.0           2263.0
# 2       1904102          2284.0          2313.0           2242.0
# 3       1906102          2294.0          2273.0           2218.0
# 4       1907110          2256.0          2205.0           2200.0
# ...         ...             ...             ...              ...
# 4230  252903101          2270.0          2241.0           2193.0
# 4231  253901101          2208.0          2189.0           2109.0
# 4232  253901106          2198.0          2253.0           2172.0
# 4233  253901107          2190.0          2178.0           2155.0
# 4236  254902101          2204.0          2159.0           2181.0
#
#       m_all_rs_fourth  r_all_rs_fifth  m_all_rs_fifth            CNAME  \
# 0              2227.0          2308.0          2317.0        CAYUGA EL
# 1              2192.0          2193.0          2153.0       ELKHART EL
# 2              2152.0          2288.0          2256.0     FRANKSTON EL
# 3              2096.0          2298.0          2312.0        NECHES EL
# 4              2168.0          2218.0          2269.0         STORY EL
# ...               ...             ...             ...              ...
# 4230           2234.0          2188.0          2313.0         OLNEY EL
# 4231           2086.0          1985.0          2088.0     BENAVIDES EL
# 4232           2181.0          2140.0          2202.0  ZAPATA SOUTH EL
# 4233           2171.0          2076.0          2168.0   ZAPATA CENTRAL
# 4236           2224.0          2122.0          2211.0      LA PRYOR EL
#
#       actual    predicted
# 0     2392.0  2330.500194
# 1     2263.0  2213.786905
# 2     2242.0  2235.007503
# 3     2218.0  2242.586288
# 4     2200.0  2213.786905
# ...      ...          ...
# 4230  2193.0  2224.397204
# 4231  2109.0  2177.408737
# 4232  2172.0  2169.829952
# 4233  2155.0  2163.766925
# 4236  2181.0  2174.377223
#
# [3557 rows x 10 columns]

# %%
# showing the residuals
df['error'] = results.resid
df['error_std_dev'] = df.error/df.error.std()
df.sort_values(by='error_std_dev', ascending=False)
# Out:
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_17793/3769534445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/bp/5dzvdsg55xn25gp9vjh1f4xc0000gn/T/ipykernel_17793/3769534445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  \
# 799    57905115          2160.0          2168.0           2470.0
# 105    15803101          2113.0          2264.0           2349.0
# 443    24801101          2093.0          2015.0           2328.0
# 2525  131001103          2355.0          2342.0           2509.0
# 1657  101814102          2085.0          1972.0           2277.0
# ...         ...             ...             ...              ...
# 112    15815101          2341.0          2299.0           2060.0
# 1809  101912103          2398.0          2198.0           2101.0
# 1110   57920108          2501.0          2338.0           2168.0
# 712    50901101          2503.0          2303.0           2169.0
# 2765  167904001          2378.0          2325.0           2070.0
#
#       m_all_rs_fourth  r_all_rs_fifth  m_all_rs_fifth            CNAME  \
# 799            2394.0          2127.0          2209.0  HARRELL BUDD EL
# 105            2253.0             NaN             NaN  HIGGS/CARTER/KI
# 443            2042.0             NaN             NaN    ENCINO SCHOOL
# 2525           2520.0             NaN             NaN        SARITA EL
# 1657           2250.0          2061.0          2171.0  THE VARNETT SCH
# ...               ...             ...             ...              ...
# 112            2021.0          2223.0          2177.0  RADIANCE ACADEM
# 1809           2025.0          2158.0          2186.0         ALLEN EL
# 1110           2159.0          2174.0          2203.0        WILMER EL
# 712            2136.0          2243.0          2201.0         EVANT EL
# 2765           2119.0          2105.0          2147.0    PRIDDY SCHOOL
#
#       actual    predicted       error  error_std_dev
# 799   2470.0  2141.030570  328.969430       6.688436
# 105   2349.0  2105.410280  243.589720       4.952540
# 443   2328.0  2090.252710  237.747290       4.833755
# 2525  2509.0  2288.816877  220.183123       4.476649
# 1657  2277.0  2084.189682  192.810318       3.920119
# ...      ...          ...         ...            ...
# 112   2060.0  2278.206578 -218.206578      -4.436463
# 1809  2101.0  2321.405652 -220.405652      -4.481174
# 1110  2168.0  2399.467137 -231.467137      -4.706070
# 712   2169.0  2400.982894 -231.982894      -4.716556
# 2765  2070.0  2306.248082 -236.248082      -4.803274
#
# [3557 rows x 12 columns]

# %% [markdown]
# # Finding suspicious datapoints with linear regression
#
# Is Harrell Budd Elementary's fourth grade reading classrooms the only place where we see cheating in 2004?
#
# How else can you design regressions to help you uncover other instances of cheating?
#
# In the cells below, try to define your own questions and see if you can uncover other suspicious scores using regressions. You may also want to use plots as necessary. You can start with reading (`r_all_rs`) and math (`m_all_rs`) scores in the data we have loaded, but if you'd like, you're also welcome to bring in other variables from the [data documentation](
# https://tea.texas.gov/sites/default/files/TAKS-Variables-prior2005.pdf).
#
# - If you've got an interesting finding, put up a green sticky note! 🟩
#
# - If you're stuck, put up a red sticky note! 🟥

# %% [markdown]
# ## Load the data again

# %%
df_third_grade_2004 = pd.read_csv("data/cfy04e3.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_third')
df_fourth_grade_2004 = pd.read_csv("data/cfy04e4.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_fourth')
df_fifth_grade_2004 = pd.read_csv("data/cfy04e5.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_fifth')

# This time I'm also adding fourth grade scores from last year (2003)! 
df_fourth_grade_2003 = pd.read_csv("data/cfy04e3.dat", usecols=['r_all_rs', 'm_all_rs', 'CNAME', 'CAMPUS']).set_index('CAMPUS').add_suffix('_fourth_last_year')

df_04_03 = pd.concat([df_third_grade_2004, df_fourth_grade_2004, df_fifth_grade_2004, df_fourth_grade_2003], axis=1)
df_04_03['CNAME'] = df_04_03['CNAME_third'].fillna(df_04_03['CNAME_fourth']).fillna(df_04_03['CNAME_fifth']).fillna(df_04_03['CNAME_fourth_last_year'])
df_04_03 = df_04_03.drop(columns=['CNAME_third', 'CNAME_fourth', 'CNAME_fifth', 'CNAME_fourth_last_year'])


# Note, I changed the variable name from df so I don't override your previous work
df_04_03
# Out:
#            r_all_rs_third  m_all_rs_third  r_all_rs_fourth  m_all_rs_fourth  \
# CAMPUS
# 1902103            2410.0          2388.0           2392.0           2227.0
# 1903101            2256.0          2208.0           2263.0           2192.0
# 1904102            2284.0          2313.0           2242.0           2152.0
# 1906102            2294.0          2273.0           2218.0           2096.0
# 1907110            2256.0          2205.0           2200.0           2168.0
# ...                   ...             ...              ...              ...
# 253901106          2198.0          2253.0           2172.0           2181.0
# 253901107          2190.0          2178.0           2155.0           2171.0
# 254901104             NaN             NaN           2176.0           2148.0
# 254901105          2183.0          2180.0              NaN              NaN
# 254902101          2204.0          2159.0           2181.0           2224.0
#
#            r_all_rs_fifth  m_all_rs_fifth  r_all_rs_fourth_last_year  \
# CAMPUS
# 1902103            2308.0          2317.0                     2410.0
# 1903101            2193.0          2153.0                     2256.0
# 1904102            2288.0          2256.0                     2284.0
# 1906102            2298.0          2312.0                     2294.0
# 1907110            2218.0          2269.0                     2256.0
# ...                   ...             ...                        ...
# 253901106          2140.0          2202.0                     2198.0
# 253901107          2076.0          2168.0                     2190.0
# 254901104          2089.0          2053.0                        NaN
# 254901105             NaN             NaN                     2183.0
# 254902101          2122.0          2211.0                     2204.0
#
#            m_all_rs_fourth_last_year            CNAME
# CAMPUS
# 1902103                       2388.0        CAYUGA EL
# 1903101                       2208.0       ELKHART EL
# 1904102                       2313.0     FRANKSTON EL
# 1906102                       2273.0        NECHES EL
# 1907110                       2205.0         STORY EL
# ...                              ...              ...
# 253901106                     2253.0  ZAPATA SOUTH EL
# 253901107                     2178.0   ZAPATA CENTRAL
# 254901104                        NaN  BENITO JUAREZ E
# 254901105                     2180.0  LORENZO DE ZAVA
# 254902101                     2159.0      LA PRYOR EL
#
# [4237 rows x 9 columns]

# %%
to_plot = df.query('r_all_rs_fifth.notna()')

(
    ggplot(to_plot, aes(x='r_all_rs_fourth')) + 
        geom_histogram(bins=20)
)
# Out:
# <ggplot: (378017229)>

# %%
# Comparing actual to predicted values
df['actual'] = df.r_all_rs_fourth
df['predicted'] = results.predict()
df.head()
# Out:
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/664343168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/664343168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  m_all_rs_fourth  \
# 0  1902103          2410.0          2388.0           2392.0           2227.0
# 1  1903101          2256.0          2208.0           2263.0           2192.0
# 2  1904102          2284.0          2313.0           2242.0           2152.0
# 3  1906102          2294.0          2273.0           2218.0           2096.0
# 4  1907110          2256.0          2205.0           2200.0           2168.0
#
#    r_all_rs_fifth  m_all_rs_fifth         CNAME  actual    predicted
# 0          2308.0          2317.0     CAYUGA EL  2392.0  2287.641642
# 1          2193.0          2153.0    ELKHART EL  2263.0  2219.254770
# 2          2288.0          2256.0  FRANKSTON EL  2242.0  2275.748273
# 3          2298.0          2312.0     NECHES EL  2218.0  2281.694958
# 4          2218.0          2269.0      STORY EL  2200.0  2234.121482

# %%
df['error'] = results.resid
df['error_std_dev'] = df.error/df.error.std()
df.sort_values(by='error_std_dev', ascending=False)
# Out:
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/663163707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/c4/ch89cvbs21d4cvs_ch64f2rh0000gn/T/ipykernel_12640/663163707.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          CAMPUS  r_all_rs_third  m_all_rs_third  r_all_rs_fourth  \
# 2668  123803101          2217.0          2329.0           2313.0
# 891    57905115          2160.0          2168.0           2470.0
# 3235  180901101          2363.0          2385.0           2448.0
# 754    44904001          2266.0          2139.0           2391.0
# 1325   62906101          2284.0          2273.0           2384.0
# ...         ...             ...             ...              ...
# 131    15815101          2341.0          2299.0           2060.0
# 1828  101805101          2296.0          2166.0           2184.0
# 2386  105802041          2135.0          2113.0           2025.0
# 385    18903001          2234.0          2152.0           1999.0
# 2698  123910110          2294.0          2218.0           2117.0
#
#       m_all_rs_fourth  r_all_rs_fifth  m_all_rs_fifth            CNAME  \
# 2668           2309.0          1805.0          1816.0  TEKOA ACADEMY O
# 891            2394.0          2127.0          2209.0  HARRELL BUDD EL
# 3235           2397.0          2169.0          2126.0  MIMI FARLEY ELE
# 754            2292.0          2136.0          2143.0  SAMNORWOOD SCHO
# 1325           2327.0          2165.0          2264.0   MEYERSVILLE EL
# ...               ...             ...             ...              ...
# 131            2021.0          2223.0          2177.0  RADIANCE ACADEM
# 1828           2111.0          2443.0          2262.0  GIRLS & BOYS PR
# 2386           1964.0          2203.0          1968.0  SAN MARCOS PREP
# 385            2014.0          2162.0          2245.0    MORGAN SCHOOL
# 2698           2146.0          2376.0          2435.0      FLETCHER EL
#
#       actual    predicted       error  error_std_dev
# 2668  2313.0  1988.523411  324.476589       7.398099
# 891   2470.0  2180.006652  289.993348       6.611878
# 3235  2448.0  2204.982727  243.017273       5.540818
# 754   2391.0  2185.358669  205.641331       4.688643
# 1325  2384.0  2202.604054  181.395946       4.135846
# ...      ...          ...         ...            ...
# 131   2060.0  2237.094824 -177.094824      -4.037780
# 1828  2184.0  2367.921883 -183.921883      -4.193437
# 2386  2025.0  2225.201455 -200.201455      -4.564613
# 385   1999.0  2200.820048 -201.820048      -4.601517
# 2698  2117.0  2328.079097 -211.079097      -4.812625
#
# [3066 rows x 12 columns]

# %%
ggplot(df, )

# %%
df = df.query('r_all_rs_fourth.notna() and r_all_rs_third.notna()')
model = smf.ols("r_all_rs_fourth ~ r_all_rs_third", data=df)

results = model.fit()
results.summary()

# %%
# Summary

to_plot = df.query('r_all_rs_fourth.notna() and r_all_rs_fifth.notna()')
to_highlight = to_plot.query('CNAME.str.contains(\'HARRELL BUDD\')')

(
    ggplot(to_plot, aes(x='r_all_rs_fifth', y='r_all_rs_fourth')) + 
        geom_point() + 
        geom_smooth(method='lm', color='red') + 
        geom_point(data=to_highlight, color='red')
)
# Out:
# <ggplot: (378040236)>

# %%
#Model

df = df.query('r_all_rs_fourth.notna() and r_all_rs_fifth.notna()')
model = smf.ols("r_all_rs_fourth ~ r_all_rs_fifth", data=df)

results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        r_all_rs_fourth   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     4587.
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):               0.00
# Time:                        15:53:07   Log-Likelihood:                -15942.
# No. Observations:                3066   AIC:                         3.189e+04
# Df Residuals:                    3064   BIC:                         3.190e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        915.1469     19.356     47.280      0.000     877.195     953.098
# r_all_rs_fifth     0.5947      0.009     67.731      0.000       0.577       0.612
# ==============================================================================
# Omnibus:                      232.508   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1260.355
# Skew:                           0.059   Prob(JB):                    2.08e-274
# Kurtosis:                       6.139   Cond. No.                     5.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Bonus 🤖 (very optional)
#
# This loads a giant dataframe with all of the columns from 2004 (there are 2827 columns 😲).
#
# Here is the documentation for those columns:
# https://tea.texas.gov/sites/default/files/TAKS-Variables-prior2005.pdf
#
# How would you use the additional data? What variables will you target first? Design more statstical inquiry that takes advantage of the full dataset.

# %%
df_third_grade_2004 = pd.read_csv("data/cfy04e3.dat").set_index('CAMPUS').assign(grade='third')
df_fourth_grade_2004 = pd.read_csv("data/cfy04e4.dat").set_index('CAMPUS').assign(grade='fourth')
df_fifth_grade_2004 = pd.read_csv("data/cfy04e5.dat").set_index('CAMPUS').assign(grade='fifth')

df_2004 = pd.concat([df_third_grade_2004, df_fourth_grade_2004, df_fifth_grade_2004])
df_2004
# Out:
#            DISTRICT  MONTH  YEAR  GRADE  REGION            DNAME  \
# CAMPUS
# 1902103        1902      3     4      3       7       CAYUGA ISD
# 1903101        1903      3     4      3       7      ELKHART ISD
# 1904102        1904      4     4      3       7    FRANKSTON ISD
# 1906102        1906      3     4      3       7       NECHES ISD
# 1907110        1907      4     4      3       7    PALESTINE ISD
# ...             ...    ...   ...    ...     ...              ...
# 253901101    253901      4     4      5       1  ZAPATA COUNTY I
# 253901106    253901      4     4      5       1  ZAPATA COUNTY I
# 253901107    253901      4     4      5       1  ZAPATA COUNTY I
# 254901104    254901      4     4      5      20  CRYSTAL CITY IS
# 254902101    254902      4     4      5      20     LA PRYOR ISD
#
#                      CNAME  STATE  a_docs  a_tst_n  a_abs_n  a_lep_n  a_oth_n  \
# CAMPUS
# 1902103          CAYUGA EL      1    34.0     29.0        0        0        5
# 1903101         ELKHART EL      1    94.0     80.0        0        0       14
# 1904102       FRANKSTON EL      1    59.0     52.0        0        1        6
# 1906102          NECHES EL      1    20.0     16.0        0        0        4
# 1907110           STORY EL      1   266.0    244.0        0        2       20
# ...                    ...    ...     ...      ...      ...      ...      ...
# 253901101     BENAVIDES EL      1     NaN      NaN        0        0        1
# 253901106  ZAPATA SOUTH EL      1     NaN      NaN        0        0       17
# 253901107   ZAPATA CENTRAL      1     NaN      NaN        0        0       11
# 254901104  BENITO JUAREZ E      1     NaN      NaN        0        0       11
# 254902101      LA PRYOR EL      1     NaN      NaN        0        0        9
#
#            a_all_d  a_sexm_d  a_sexf_d  a_sexv_d  a_ethi_d  a_etha_d  \
# CAMPUS
# 1902103         29        13        16         0         0         0
# 1903101         80        41        39         0         0         0
# 1904102         52        33        17         2         0         0
# 1906102         16        10         6         0         0         0
# 1907110        244       125       119         0         0         5
# ...            ...       ...       ...       ...       ...       ...
# 253901101        6         4         2         0         0         0
# 253901106       89        38        51         0         0         0
# 253901107       91        46        44         1         0         1
# 254901104      143        65        78         0         0         0
# 254902101       54        29        25         0         0         0
#
#            a_ethb_d  a_ethh_d  a_ethw_d  a_ethv_d  a_econ_d  a_eco1_d  \
# CAMPUS
# 1902103           3         1        25         0        24         3
# 1903101           4         4        72         0        45        26
# 1904102           7         2        40         3        27        16
# 1906102           2         0        14         0        10         6
# 1907110          70        77        92         0        93       131
# ...             ...       ...       ...       ...       ...       ...
# 253901101         0         6         0         0         1         4
# 253901106         0        84         5         0        17        55
# 253901107         0        90         0         0        13        69
# 254901104         0       143         0         0        18       107
# 254902101         1        51         2         0         4        42
#
#            a_eco2_d  a_eco9_d  a_ecov_d  a_ecoy_d  a_vocn_d  a_voce_d  \
# CAMPUS
# 1902103           2         0         0         5         0         0
# 1903101           9         0         0        35         0         0
# 1904102           5         0         4        21         0         0
# 1906102           0         0         0         6         0         0
# 1907110          20         0         0       151         0         0
# ...             ...       ...       ...       ...       ...       ...
# 253901101         1         0         0         5         0         0
# 253901106         5        12         0        72         0         0
# 253901107         6         2         1        77         0         0
# 254901104         8        10         0       125         0         0
# 254902101         8         0         0        50         0         0
#
#            a_vocs_d  a_vocp_d  a_vocv_d  a_vocy_d  a_ti1n_d  a_ti1y_d  \
# CAMPUS
# 1902103           0         0        29         0        24         5
# 1903101           0         0        80         0         0        80
# 1904102           0         0        52         0         2        47
# 1906102           0         0        16         0         0        16
# 1907110           0         0       244         0         7       237
# ...             ...       ...       ...       ...       ...       ...
# 253901101         0         0         6         0         0         6
# 253901106         0         0        89         0         1        88
# 253901107         0         0        91         0        11        79
# 254901104         0         0       143         0         0       143
# 254902101         0         0        54         0         0        54
#
#            a_ti1v_d  a_ti18_d  a_ti16_d  a_ti17_d  a_ti19_d  a_mign_d  \
# CAMPUS
# 1902103           0         1         0         5         0        29
# 1903101           0         0        80         0         0        80
# 1904102           3         0        47         0         0        49
# 1906102           0         0        16         0         0        16
# 1907110           0         0       237         0         0       244
# ...             ...       ...       ...       ...       ...       ...
# 253901101         0         0         6         0         0         5
# 253901106         0         0        88         0         0        84
# 253901107         1         0        79         0         0        83
# 254901104         0         0       143         0         0       106
# 254902101         0         0        54         0         0        33
#
#            a_migy_d  a_migv_d  a_lepn_d  a_lepy_d  a_lepv_d  a_biln_d  \
# CAMPUS
# 1902103           0         0        29         0         0        29
# 1903101           0         0        80         0         0        80
# 1904102           0         3        48         1         3        48
# 1906102           0         0        16         0         0        16
# 1907110           0         0       227        17         0       244
# ...             ...       ...       ...       ...       ...       ...
# 253901101         1         0         1         5         0         2
# 253901106         4         1        71        18         0        73
# 253901107         6         2        47        44         0        58
# 254901104        37         0       120        23         0       120
# 254902101        21         0        52         2         0        54
#
#            a_bily_d  a_bilv_d  a_esln_d  a_esly_d  a_eslv_d  a_spen_d  \
# CAMPUS
# 1902103           0         0        29         0         0        27
# 1903101           0         0        80         0         0        76
# 1904102           1         3        49         0         3        46
# 1906102           0         0        16         0         0        13
# 1907110           0         0       226        18         0       240
# ...             ...       ...       ...       ...       ...       ...
# 253901101         4         0         6         0         0         5
# 253901106        16         0        89         0         0        86
# 253901107        33         0        91         0         0        91
# 254901104        23         0       143         0         0       136
# 254902101         0         0        52         2         0        53
#
#            a_spey_d  a_spev_d  a_gifn_d  a_gify_d  a_gifv_d  a_atrn_d  \
# CAMPUS
# 1902103           2         0        26         3         0        23
# 1903101           4         0        77         3         0        58
# 1904102           3         3        47         2         3        36
# 1906102           3         0        13         3         0        10
# 1907110           4         0       231        13         0       134
# ...             ...       ...       ...       ...       ...       ...
# 253901101         1         0         6         0         0         1
# 253901106         3         0        83         6         0        29
# 253901107         0         0        87         4         0        49
# 254901104         7         0       130        13         0        68
# 254902101         1         0        48         6         0        30
#
#            a_atry_d  a_atrv_d  a_all_NM  a_sexm_NM  a_sexf_NM  a_sexv_NM  \
# CAMPUS
# 1902103           6         0      29.0       13.0       16.0        NaN
# 1903101          22         0      66.0       35.0       31.0        NaN
# 1904102          13         3      48.0       30.0       16.0        NaN
# 1906102           6         0      13.0        8.0        5.0        NaN
# 1907110         110         0     195.0       95.0      100.0        NaN
# ...             ...       ...       ...        ...        ...        ...
# 253901101         5         0       2.0        NaN        NaN        NaN
# 253901106        60         0      48.0       25.0       23.0        NaN
# 253901107        41         1      33.0       18.0       15.0        NaN
# 254901104        75         0      54.0       21.0       33.0        NaN
# 254902101        24         0      20.0       13.0        7.0        NaN
#
#            a_ethi_NM  a_etha_NM  a_ethb_NM  a_ethh_NM  a_ethw_NM  a_ethv_NM  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN       25.0        NaN
# 1903101          NaN        NaN        NaN        NaN       61.0        NaN
# 1904102          NaN        NaN        7.0        NaN       37.0        NaN
# 1906102          NaN        NaN        NaN        NaN       12.0        NaN
# 1907110          NaN        5.0       45.0       65.0       80.0        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        NaN        2.0        NaN        NaN
# 253901106        NaN        NaN        NaN       44.0        4.0        NaN
# 253901107        NaN        NaN        NaN       32.0        NaN        NaN
# 254901104        NaN        NaN        NaN       54.0        NaN        NaN
# 254902101        NaN        NaN        NaN       20.0        NaN        NaN
#
#            a_econ_NM  a_eco1_NM  a_eco2_NM  a_eco9_NM  a_ecov_NM  a_ecoy_NM  \
# CAMPUS
# 1902103         24.0        NaN        NaN        NaN        NaN        5.0
# 1903101         38.0       23.0        5.0        NaN        NaN       28.0
# 1904102         24.0       15.0        5.0        NaN        NaN       20.0
# 1906102          9.0        4.0        NaN        NaN        NaN        4.0
# 1907110         81.0       95.0       19.0        NaN        NaN      114.0
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        NaN        NaN        NaN        2.0
# 253901106       12.0       29.0        3.0        4.0        NaN       36.0
# 253901107        7.0       24.0        1.0        NaN        NaN       26.0
# 254901104       13.0       31.0        6.0        4.0        NaN       41.0
# 254902101        NaN       14.0        5.0        NaN        NaN       19.0
#
#            a_vocn_NM  a_voce_NM  a_vocs_NM  a_vocp_NM  a_vocv_NM  a_vocy_NM  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN       29.0        NaN
# 1903101          NaN        NaN        NaN        NaN       66.0        NaN
# 1904102          NaN        NaN        NaN        NaN       48.0        NaN
# 1906102          NaN        NaN        NaN        NaN       13.0        NaN
# 1907110          NaN        NaN        NaN        NaN      195.0        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        NaN        NaN        2.0        NaN
# 253901106        NaN        NaN        NaN        NaN       48.0        NaN
# 253901107        NaN        NaN        NaN        NaN       33.0        NaN
# 254901104        NaN        NaN        NaN        NaN       54.0        NaN
# 254902101        NaN        NaN        NaN        NaN       20.0        NaN
#
#            a_ti1n_NM  a_ti1y_NM  a_ti1v_NM  a_ti18_NM  a_ti16_NM  a_ti17_NM  \
# CAMPUS
# 1902103         24.0        5.0        NaN        NaN        NaN        5.0
# 1903101          NaN       66.0        NaN        NaN       66.0        NaN
# 1904102          NaN       45.0        NaN        NaN       45.0        NaN
# 1906102          NaN       13.0        NaN        NaN       13.0        NaN
# 1907110          6.0      189.0        NaN        NaN      189.0        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        2.0        NaN        NaN        2.0        NaN
# 253901106        NaN       47.0        NaN        NaN       47.0        NaN
# 253901107        3.0       30.0        NaN        NaN       30.0        NaN
# 254901104        NaN       54.0        NaN        NaN       54.0        NaN
# 254902101        NaN       20.0        NaN        NaN       20.0        NaN
#
#            a_ti19_NM  a_mign_NM  a_migy_NM  a_migv_NM  a_lepn_NM  a_lepy_NM  \
# CAMPUS
# 1902103          NaN       29.0        NaN        NaN       29.0        NaN
# 1903101          NaN       66.0        NaN        NaN       66.0        NaN
# 1904102          NaN       45.0        NaN        NaN       45.0        NaN
# 1906102          NaN       13.0        NaN        NaN       13.0        NaN
# 1907110          NaN      195.0        NaN        NaN      183.0       12.0
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        2.0        NaN        NaN        NaN        2.0
# 253901106        NaN       46.0        NaN        NaN       45.0        3.0
# 253901107        NaN       33.0        0.0        NaN       28.0        5.0
# 254901104        NaN       45.0        9.0        NaN       54.0        0.0
# 254902101        NaN       14.0        6.0        NaN       20.0        NaN
#
#            a_lepv_NM  a_biln_NM  a_bily_NM  ...  s_ethw_rpr  s_ethv_rpr  \
# CAMPUS                                      ...
# 1902103          NaN       29.0        NaN  ...         NaN         NaN
# 1903101          NaN       66.0        NaN  ...         NaN         NaN
# 1904102          NaN       45.0        NaN  ...         NaN         NaN
# 1906102          NaN       13.0        NaN  ...         NaN         NaN
# 1907110          NaN      195.0        NaN  ...         NaN         NaN
# ...              ...        ...        ...  ...         ...         ...
# 253901101        NaN        NaN        NaN  ...         NaN         NaN
# 253901106        NaN       46.0        2.0  ...        80.0         NaN
# 253901107        NaN       31.0        2.0  ...         NaN         NaN
# 254901104        NaN       54.0        0.0  ...         NaN         NaN
# 254902101        NaN       20.0        NaN  ...         NaN         NaN
#
#            s_ti1y_rpr  s_ti1n_rpr  s_ti1v_rpr  s_migy_rpr  s_mign_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         0.0         NaN         NaN         NaN         0.0
# 253901106        43.0         NaN         NaN         NaN        43.0
# 253901107        33.0        18.0         NaN         0.0        34.0
# 254901104        28.0         NaN         NaN        17.0        32.0
# 254902101        28.0         NaN         NaN        24.0        30.0
#
#            s_migv_rpr  s_lepy_rpr  s_lepn_rpr  s_lepv_rpr  s_bily_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         0.0         NaN         NaN         NaN
# 253901106         NaN         6.0        54.0         NaN         6.0
# 253901107         NaN        11.0        49.0         NaN         9.0
# 254901104         NaN         5.0        33.0         NaN         5.0
# 254902101         NaN         NaN        29.0         NaN         NaN
#
#            s_biln_rpr  s_bilv_rpr  s_esly_rpr  s_esln_rpr  s_eslv_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         NaN         NaN         0.0         NaN
# 253901106        52.0         NaN         NaN        44.0         NaN
# 253901107        43.0         NaN         NaN        31.0         NaN
# 254901104        33.0         NaN         NaN        28.0         NaN
# 254902101        28.0         NaN         NaN        29.0         NaN
#
#            s_spey_rpr  s_spen_rpr  s_spev_rpr  s_gify_rpr  s_gifn_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         0.0         NaN         NaN         0.0
# 253901106         NaN        44.0         NaN       100.0        40.0
# 253901107         NaN        31.0         NaN         NaN        28.0
# 254901104        33.0        28.0         NaN        92.0        22.0
# 254902101         NaN        28.0         NaN        67.0        23.0
#
#            s_gifv_rpr  s_atry_rpr  s_atrn_rpr  s_atrv_rpr  s_vocy_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         0.0         NaN         NaN         NaN
# 253901106         NaN        28.0        76.0         NaN         NaN
# 253901107         NaN        12.0        47.0         NaN         NaN
# 254901104         NaN        12.0        46.0         NaN         NaN
# 254902101         NaN        21.0        33.0         NaN         NaN
#
#            s_vocn_rpr  s_vocv_rpr  s_ti16_rpr  s_ti17_rpr  s_ti18_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         0.0         0.0         NaN         NaN
# 253901106         NaN        44.0        43.0         NaN         NaN
# 253901107         NaN        31.0        33.0         NaN         NaN
# 254901104         NaN        28.0        28.0         NaN         NaN
# 254902101         NaN        28.0        28.0         NaN         NaN
#
#            s_ti19_rpr  s_eco1_rpr  s_eco2_rpr  s_eco9_rpr  s_voce_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         NaN         NaN         NaN         NaN
# 253901106         NaN        42.0        60.0        33.0         NaN
# 253901107         NaN        30.0         0.0         NaN         NaN
# 254901104         NaN        25.0        50.0        20.0         NaN
# 254902101         NaN        24.0        38.0         NaN         NaN
#
#            s_vocs_rpr  s_vocp_rpr  s_ecoy_rpr  s_econ_rpr  s_ecov_rpr  \
# CAMPUS
# 1902103           NaN         NaN         NaN         NaN         NaN
# 1903101           NaN         NaN         NaN         NaN         NaN
# 1904102           NaN         NaN         NaN         NaN         NaN
# 1906102           NaN         NaN         NaN         NaN         NaN
# 1907110           NaN         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 253901101         NaN         NaN         0.0         NaN         NaN
# 253901106         NaN         NaN        42.0        53.0         NaN
# 253901107         NaN         NaN        27.0        54.0         NaN
# 254901104         NaN         NaN        26.0        47.0         NaN
# 254902101         NaN         NaN        26.0         NaN         NaN
#
#            s_all_rs  s_sexm_rs  s_sexf_rs  s_sexv_rs  s_ethi_rs  s_etha_rs  \
# CAMPUS
# 1902103         NaN        NaN        NaN        NaN        NaN        NaN
# 1903101         NaN        NaN        NaN        NaN        NaN        NaN
# 1904102         NaN        NaN        NaN        NaN        NaN        NaN
# 1906102         NaN        NaN        NaN        NaN        NaN        NaN
# 1907110         NaN        NaN        NaN        NaN        NaN        NaN
# ...             ...        ...        ...        ...        ...        ...
# 253901101    1891.0        NaN        NaN        NaN        NaN        NaN
# 253901106    2038.0     2080.0     2007.0        NaN        NaN        NaN
# 253901107    1977.0     2006.0     1953.0        NaN        NaN        NaN
# 254901104    2008.0     1999.0     2015.0        NaN        NaN        NaN
# 254902101    2008.0     2048.0     1960.0        NaN        NaN        NaN
#
#            s_ethb_rs  s_ethh_rs  s_ethw_rs  s_ethv_rs  s_ti1y_rs  s_ti1n_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN     1891.0        NaN        NaN     1891.0        NaN
# 253901106        NaN     2031.0     2154.0        NaN     2035.0        NaN
# 253901107        NaN     1976.0        NaN        NaN     1990.0     1908.0
# 254901104        NaN     2008.0        NaN        NaN     2008.0        NaN
# 254902101        NaN     2014.0        NaN        NaN     2008.0        NaN
#
#            s_ti1v_rs  s_migy_rs  s_mign_rs  s_migv_rs  s_lepy_rs  s_lepn_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN     1881.0        NaN     1890.0        NaN
# 253901106        NaN        NaN     2033.0        NaN     1878.0     2079.0
# 253901107        NaN     1809.0     1994.0        NaN     1883.0     2066.0
# 254901104        NaN     1988.0     2014.0        NaN     1879.0     2031.0
# 254902101        NaN     1995.0     2016.0        NaN        NaN     2015.0
#
#            s_lepv_rs  s_bily_rs  s_biln_rs  s_bilv_rs  s_esly_rs  s_esln_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        NaN        NaN        NaN     1891.0
# 253901106        NaN     1869.0     2076.0        NaN        NaN     2038.0
# 253901107        NaN     1855.0     2047.0        NaN        NaN     1977.0
# 254901104        NaN     1879.0     2032.0        NaN        NaN     2008.0
# 254902101        NaN        NaN     2008.0        NaN        NaN     2015.0
#
#            s_eslv_rs  s_spey_rs  s_spen_rs  s_spev_rs  s_gify_rs  s_gifn_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN     1866.0        NaN        NaN     1891.0
# 253901106        NaN        NaN     2036.0        NaN     2257.0     2021.0
# 253901107        NaN        NaN     1977.0        NaN        NaN     1964.0
# 254901104        NaN     1964.0     2010.0        NaN     2230.0     1985.0
# 254902101        NaN        NaN     2007.0        NaN     2173.0     1987.0
#
#            s_gifv_rs  s_atry_rs  s_atrn_rs  s_atrv_rs  s_vocy_rs  s_vocn_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN     1890.0        NaN        NaN        NaN        NaN
# 253901106        NaN     1966.0     2181.0        NaN        NaN        NaN
# 253901107        NaN     1887.0     2058.0        NaN        NaN        NaN
# 254901104        NaN     1922.0     2102.0        NaN        NaN        NaN
# 254902101        NaN     1957.0     2048.0        NaN        NaN        NaN
#
#            s_vocv_rs  s_ti16_rs  s_ti17_rs  s_ti18_rs  s_ti19_rs  s_eco1_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101     1891.0     1891.0        NaN        NaN        NaN        NaN
# 253901106     2038.0     2035.0        NaN        NaN        NaN     2019.0
# 253901107     1977.0     1990.0        NaN        NaN        NaN     1972.0
# 254901104     2008.0     2008.0        NaN        NaN        NaN     1986.0
# 254902101     2008.0     2008.0        NaN        NaN        NaN     1994.0
#
#            s_eco2_rs  s_eco9_rs  s_voce_rs  s_vocs_rs  s_vocp_rs  s_ecoy_rs  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        NaN        NaN        NaN     1890.0
# 253901106     2103.0     2007.0        NaN        NaN        NaN     2022.0
# 253901107     1925.0        NaN        NaN        NaN        NaN     1969.0
# 254901104     2152.0     1990.0        NaN        NaN        NaN     1997.0
# 254902101     2057.0        NaN        NaN        NaN        NaN     2004.0
#
#            s_econ_rs  s_ecov_rs  s_obj1_NI  s_obj1_RI  s_obj2_NI  s_obj2_RI  \
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 253901101        NaN        NaN        8.7       67.0        5.3       59.0
# 253901106     2111.0        NaN        9.9       76.0        7.3       81.0
# 253901107     2046.0        NaN        9.1       70.0        6.5       72.0
# 254901104     2084.0        NaN        9.9       76.0        6.2       69.0
# 254902101        NaN        NaN       10.1       78.0        6.5       72.0
#
#            s_obj3_NI  s_obj3_RI  s_obj4_NI  s_obj4_RI
# CAMPUS
# 1902103          NaN        NaN        NaN        NaN
# 1903101          NaN        NaN        NaN        NaN
# 1904102          NaN        NaN        NaN        NaN
# 1906102          NaN        NaN        NaN        NaN
# 1907110          NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...
# 253901101        4.7       52.0        3.8       43.0
# 253901106        6.1       68.0        4.5       50.0
# 253901107        5.5       62.0        4.2       47.0
# 254901104        6.0       67.0        4.7       52.0
# 254902101        5.7       64.0        4.3       48.0
#
# [11161 rows x 2827 columns]
